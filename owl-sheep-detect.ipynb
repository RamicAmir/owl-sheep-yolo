# %% [markdown]
# Import downloaded data from gdrive

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/ My Drive/Colab Notebooks/owl-sheep'

# %% [markdown]
# Install ultralytics library

# %%
# !pip install ultralytics

# %% [markdown]
# Step 1. Use YOLO from ultralytics library, create new model and use the config.yaml file which contains the root dir for training data.
#
# Step 2. run code and train data for 100 epochs, the results will be stored in a map named /runs.

# %%
import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# use the model
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=100)  # train the model
# Out:
# Ultralytics YOLOv8.1.10 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
